# %% [markdown]
# # Connect to SQL Database

# %%
import pandas as pd 
from sqlalchemy import create_engine
import plotly.graph_objects as go

# %%
# Load and read csv
csv_file = "./data/battles.csv"
got_battles = pd.read_csv(csv_file)

json_file = "./data/character-deaths.json"
character_deaths_uncleaned = pd.read_json(json_file)

csv_file4 = "./data/scripts.csv"
got_scripts = pd.read_csv(csv_file4)

csv_file5 = "./data/ratings.csv"
got_ratings = pd.read_csv(csv_file5)

# %%
got_ratings = got_ratings.rename(columns ={
                            "Season": "season",
                            "Episode Number": "episode_number", 
                            "Number in Season": "number_in_season",
                            "Episode Name": "episode_name",
                            "Director": "director",
                            "Writer": "writer",
                            "Original Air Date":"original_air_date",
                            "US viewers (million)":"us_viewers_millions",
                            "Runtime (mins)":"runtime_mins",
                            "IMDB Description":"imdb_description",
                            "IMDB votes":"imdb_votes",
                            "Imdb Rating":"imdb_rating",
                            "Notable Death Count":"notable_death_count"
                            })

# %%
# Establish connection 

connection_string = "postgres:PW@localhost:5432/Game-of-Thrones"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Print table names
engine.table_names()

# Load data
got_battles.to_sql(name="got_battles", con=engine, if_exists='append', index=False)
got_ratings.to_sql(name="got_ratings", con=engine, if_exists='append', index=False)


# Read data using Pandas
pd.read_sql_query('select * from got_battles', con=engine)
pd.read_sql_query('select * from got_ratings', con=engine)
# Out:
#      season  episode_number  number_in_season  \
# 0         1               1                 1
# 1         1               2                 2
# 2         1               3                 3
# 3         1               4                 4
# 4         1               5                 5
# ..      ...             ...               ...
# 141       8              69                 2
# 142       8              70                 3
# 143       8              71                 4
# 144       8              72                 5
# 145       8              73                 6
#
#                               episode_name                     director  \
# 0                         Winter Is Coming               Tim Van Patten
# 1                            The Kingsroad               Tim Van Patten
# 2                                Lord Snow                   Brian Kirk
# 3    Cripples, Bastards, and Broken Things                   Brian Kirk
# 4                    The Wolf and the Lion                   Brian Kirk
# ..                                     ...                          ...
# 141         A Knight of the Seven Kingdoms                 David Nutter
# 142                         The Long Night             Miguel Sapochnik
# 143                 The Last of the Starks                 David Nutter
# 144                              The Bells             Miguel Sapochnik
# 145                        The Iron Throne  David Benioff & D. B. Weiss
#
#                           writer original_air_date us_viewers_millions  \
# 0    David Benioff & D. B. Weiss    April 17, 2011                2.22
# 1    David Benioff & D. B. Weiss    April 24, 2011                 2.2
# 2    David Benioff & D. B. Weiss       May 1, 2011                2.44
# 3                   Bryan Cogman       May 8, 2011                2.45
# 4    David Benioff & D. B. Weiss      May 15, 2011                2.58
# ..                           ...               ...                 ...
# 141                 Bryan Cogman    April 21, 2019               10.29
# 142  David Benioff & D. B. Weiss    April 28, 2019               12.02
# 143  David Benioff & D. B. Weiss       May 5, 2019                11.8
# 144  David Benioff & D. B. Weiss      May 12, 2019                12.4
# 145  David Benioff & D. B. Weiss      May 19, 2019               13.61
#
#      runtime_mins                                   imdb_description  \
# 0              62  Jon Arryn, the Hand of the King, is dead. King...
# 1              56  While Bran recovers from his fall, Ned takes o...
# 2              58  Lord Stark and his daughters arrive at King's ...
# 3              56  Eddard investigates Jon Arryn's murder. Jon be...
# 4              55  Catelyn has captured Tyrion and plans to bring...
# ..            ...                                                ...
# 141            58  Jaime faces judgment and Winterfell prepares f...
# 142            82  The Night King and his army have arrived at Wi...
# 143            78  The Battle of Winterfell is over and a new cha...
# 144            78  Forces have arrived at King's Landing for the ...
# 145            80  In the aftermath of the devastating attack on ...
#
#      imdb_votes  imdb_rating  notable_death_count
# 0         27685            9                    4
# 1         21256            9                    3
# 2         20090            9                    0
# 3         19123            9                    1
# 4         20062            9                    5
# ..          ...          ...                  ...
# 141      118605            8                    0
# 142      198482            8                    7
# 143      151229            6                    2
# 144      176140            6                    7
# 145      216879            4                    1
#
# [146 rows x 13 columns]

# %% [markdown]
# ### SQL Code
#
# ```sql
#
# DROP TABLE got_battles;
# DROP TABLE got_ratings;
#
# CREATE TABLE got_battles(
# 	name VARCHAR,
# 	year INT,
# 	battle_number INT,
# 	attacker_king VARCHAR,
# 	defender_king VARCHAR,
# 	attacker_1 VARCHAR,
# 	attacker_2 VARCHAR,
# 	attacker_3 VARCHAR,
# 	attacker_4 VARCHAR,
# 	defender_1 VARCHAR,
# 	defender_2 VARCHAR,
# 	defender_3 VARCHAR,
# 	defender_4 VARCHAR,
# 	attacker_outcome VARCHAR,
# 	battle_type VARCHAR,
# 	major_death INT,
# 	major_capture VARCHAR,
# 	attacker_size INT,
# 	defender_size INT,
# 	attacker_commander VARCHAR,
# 	defender_commander VARCHAR,
# 	summer VARCHAR,
# 	location VARCHAR,
# 	region VARCHAR,
# 	note VARCHAR
# );
#
# CREATE TABLE got_ratings(
# 	season INT,
# 	episode_number INT,
# 	number_in_season INT,
# 	episode_name VARCHAR,
# 	director VARCHAR,
# 	writer VARCHAR,
# 	original_air_date VARCHAR,
# 	us_viewers_millions VARCHAR,
# 	runtime_mins INT,
# 	imdb_description VARCHAR,
# 	imdb_votes INT,
# 	imdb_rating INT,
# 	notable_death_count INT
# );
#
# SELECT * FROM got_battles
# SELECT * FROM got_ratings
#
#
# ```

# %%
got_director_ratings = got_ratings[["director", "imdb_rating"]]

# %%
# Creating table for Top Episodes (Kasy)

got_ratings["imdb_rating"].max()

top_episodes = got_ratings.loc[got_ratings["imdb_rating"] == 9.9]

top_episodes_df = top_episodes[["season", "number_in_season", "episode_name", "director", "writer", "us_viewers_millions", "imdb_description", "imdb_votes", "imdb_rating", "notable_death_count"]]
top_episodes_df.to_csv("top_episodes.csv", index=False)

# %%
top_episodes_html = top_episodes_df.to_html()
top_episodes_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>season</th>\n      <th>number_in_season</th>\n      <th>episode_name</th>\n      <th>director</th>\n      <th>writer</th>\n      <th>us_viewers_millions</th>\n      <th>imdb_description</th>\n      <th>imdb_votes</th>\n      <th>imdb_rating</th>\n      <th>notable_death_count</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>28</th>\n      <td>3</td>\n      <td>9</td>\n      <td>The Rains of Castamere</td>\n      <td>David Nutter</td>\n      <td>David Benioff &amp; D. B. Weiss</td>\n      <td>5.22</td>\n      <td>Robb and Catelyn arrive at the Twins for the wedding. Jon is put to the test to see where his loyalties truly lie. Bran\'s group decides to split up. Daenerys plans an invasion of Yunkai.</td>\n      <td>68630</td>\n      <td>9.9</td>\n      <td>8</td>\n    </tr>\n    <tr>\n      <th>47</th>\n      <td>5</td>\n      <td>8</td>\n      <td>Hardhome</td>\n      <td>Miguel Sapochnik</td>\n      <td>David Benioff &amp; D. B. Weiss</td>\n      <td>7.01</td>\n      <td>Tyrion advises Daenerys. Sansa forces Theon to tell her a secret. Cersei remains stubborn. Arya meets her first target. Jon and Tormund meet with the wildling elders.</td>\n      <td>71476</td>\n      <td>9.9</td>\n      <td>4</td>\n    </tr>\n    <tr>\n      <th>58</th>\n      <td>6</td>\n      <td>9</td>\n      <td>Battle of the Bastards</td>\n      <td>Miguel Sapochnik</td>\n      <td>David Benioff &amp; D. B. Weiss</td>\n      <td>7.66</td>\n      <td>Jon and Sansa face Ramsay Bolton on the fields of Winterfell. Daenerys strikes back at her enemies. Theon and Yara arrive in Meereen.</td>\n      <td>159082</td>\n      <td>9.9</td>\n      <td>4</td>\n    </tr>\n    <tr>\n      <th>59</th>\n      <td>6</td>\n      <td>10</td>\n      <td>The Winds of Winter</td>\n      <td>Miguel Sapochnik</td>\n      <td>David Benioff &amp; D. B. Weiss</td>\n      <td>8.89</td>\n      <td>Cersei and Loras Tyrell stand trial by the gods. Daenerys prepares to set sail for Westeros. Davos confronts Melisandre. Sam and Gilly arrive in the Citadel. Bran discovers a long-kept secret. Lord Frey has an uninvited guest.</td>\n      <td>109392</td>\n      <td>9.9</td>\n      <td>11</td>\n    </tr>\n  </tbody>\n</table>'

# %%
director_grouped = got_director_ratings.groupby(["director"])
director_grouped.mean()

imdb_list = director_grouped["imdb_rating"]

# %%
director_group = director_grouped.mean()

# %%
director_group.to_csv("director.csv")
